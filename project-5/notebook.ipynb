# %% [markdown]
# ## 1. Darwin's bibliography
# <p><img src="https://assets.datacamp.com/production/project_607/img/CharlesDarwin.jpg" alt="Charles Darwin" width="300px"></p>
# <p>Charles Darwin is one of the few universal figures of science. His most renowned work is without a doubt his "<em>On the Origin of Species</em>" published in 1859 which introduced the concept of natural selection. But Darwin wrote many other books on a wide range of topics, including geology, plants or his personal life. In this notebook, we will automatically detect how closely related his books are to each other.</p>
# <p>To this purpose, we will develop the bases of <strong>a content-based book recommendation system</strong>, which will determine which books are close to each other based on how similar the discussed topics are. The methods we will use are commonly used in text- or documents-heavy industries such as legal, tech or customer support to perform some common task such as text classification or handling search engine queries.</p>
# <p>Let's take a look at the books we'll use in our recommendation system.</p>

# %%
# Import library
import glob

# The books files are contained in this folder
folder = "datasets/"


# List all the .txt files and sort them alphabetically
files = [file for file in  glob.glob(folder +'*.txt')]
files.sort()
# ... YOUR CODE FOR TASK 1 ...
print(files)
# Out:
# ['datasets/Autobiography.txt', 'datasets/CoralReefs.txt', 'datasets/DescentofMan.txt', 'datasets/DifferentFormsofFlowers.txt', 'datasets/EffectsCrossSelfFertilization.txt', 'datasets/ExpressionofEmotionManAnimals.txt', 'datasets/FormationVegetableMould.txt', 'datasets/FoundationsOriginofSpecies.txt', 'datasets/GeologicalObservationsSouthAmerica.txt', 'datasets/InsectivorousPlants.txt', 'datasets/LifeandLettersVol1.txt', 'datasets/LifeandLettersVol2.txt', 'datasets/MonographCirripedia.txt', 'datasets/MonographCirripediaVol2.txt', 'datasets/MovementClimbingPlants.txt', 'datasets/OriginofSpecies.txt', 'datasets/PowerMovementPlants.txt', 'datasets/VariationPlantsAnimalsDomestication.txt', 'datasets/VolcanicIslands.txt', 'datasets/VoyageBeagle.txt']

# %% [markdown]
# ## 2. Load the contents of each book into Python
# <p>As a first step, we need to load the content of these books into Python and do some basic pre-processing to facilitate the downstream analyses. We call such a collection of texts <strong>a corpus</strong>. We will also store the titles for these books for future reference and print their respective length to get a gauge for their contents.</p>

# %%
# Import libraries
import re, os

# Initialize the object that will contain the texts and titles
txts = []
titles = []

for n in files:
    # Open each file
    f = open(n, encoding='utf-8-sig')
    # Remove all non-alpha-numeric characters
    data = re.sub('[\W_]+', ' ', f.read())
    # Store the texts and titles of the books in two separate lists
    txts.append(data)
    titles.append(os.path.basename(n).replace(".txt", ""))
    
# Print the length, in characters, of each book
[len(t) for t in txts]
# Out:
# [123231,
#  496068,
#  1776539,
#  617088,
#  913713,
#  624232,
#  335920,
#  523021,
#  797401,
#  901406,
#  1047518,
#  1010643,
#  767492,
#  1660866,
#  298319,
#  916267,
#  1093567,
#  1043499,
#  341447,
#  1149574]

# %% [markdown]
# ## 3. Find "On the Origin of Species"
# <p>For the next parts of this analysis, we will often check the results returned by our method for a given book. For consistency, we will refer to Darwin's most famous book: "<em>On the Origin of Species</em>." Let's find to which index this book is associated.</p>

# %%
# Browse the list containing all the titles
for i in range(len(titles)):
    # Store the index if the title is "OriginofSpecies"
    # ... YOUR CODE FOR TASK 3 ...
    if titles[i] == "OriginofSpecies":
        ori = i
 
        

# Print the stored index
# ... YOUR CODE FOR TASK 3 ...
print(ori)
# Out:
# 15

# %% [markdown]
# ## 4. Tokenize the corpus
# <p>As a next step, we need to transform the corpus into a format that is easier to deal with for the downstream analyses. We will tokenize our corpus, i.e., transform each text into a list of the individual words (called tokens) it is made of. To check the output of our process, we will print the first 20 tokens of "<em>On the Origin of Species</em>".</p>

# %%
# Define a list of stop words
stoplist = set('for a of the and to in to be which some is at that we i who whom show via may my our might as well'.split())

# Convert the text to lower case 
txts_lower_case = [txt.lower() for txt in txts]


# Transform the text into tokens 
txts_split = [txt.split() for txt in txts_lower_case]


# Remove tokens which are part of the list of stop words
texts = [[word for word in txt if word not in stoplist] for txt in txts_split]
# Print the first 20 tokens for the "On the Origin of Species" book
# ... YOUR CODE FOR TASK 4 ...
texts[ori][0:20]
# Out:
# ['on',
#  'origin',
#  'species',
#  'but',
#  'with',
#  'regard',
#  'material',
#  'world',
#  'can',
#  'least',
#  'go',
#  'so',
#  'far',
#  'this',
#  'can',
#  'perceive',
#  'events',
#  'are',
#  'brought',
#  'about']

# %% [markdown]
# ## 5. Stemming of the tokenized corpus
# <p>If you have read <em>On the Origin of Species</em>, you will have noticed that Charles Darwin can use different words to refer to a similar concept. For example, the concept of selection can be described by words such as <em>selection</em>, <em>selective</em>, <em>select</em> or <em>selects</em>. This will dilute the weight given to this concept in the book and potentially bias the results of the analysis.</p>
# <p>To solve this issue, it is a common practice to use a <strong>stemming process</strong>, which will group together the inflected forms of a word so they can be analysed as a single item: <strong>the stem</strong>. In our <em>On the Origin of Species</em> example, the words related to the concept of selection would be gathered under the <em>select</em> stem.</p>
# <p>As we are analysing 20 full books, the stemming algorithm can take several minutes to run and, in order to make the process faster, we will directly load the final results from a pickle file and review the method used to generate it.</p>

# %%
len(texts)
# Out:
# 20

# %%
from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer("english")

texts_stem = [[stemmer.stem(word) for word in block] for block in texts]


# Print the 20 first stemmed tokens from the "On the Origin of Species" book
texts_stem[ori][0:20]
# Out:
# ['on',
#  'origin',
#  'speci',
#  'but',
#  'with',
#  'regard',
#  'materi',
#  'world',
#  'can',
#  'least',
#  'go',
#  'so',
#  'far',
#  'this',
#  'can',
#  'perceiv',
#  'event',
#  'are',
#  'brought',
#  'about']

# %% [markdown]
# ## 6. Building a bag-of-words model
# <p>Now that we have transformed the texts into stemmed tokens, we need to build models that will be useable by downstream algorithms.</p>
# <p>First, we need to will create a universe of all words contained in our corpus of Charles Darwin's books, which we call <em>a dictionary</em>. Then, using the stemmed tokens and the dictionary, we will create <strong>bag-of-words models</strong> (BoW) of each of our texts. The BoW models will represent our books as a list of all uniques tokens they contain associated with their respective number of occurrences. </p>
# <p>To better understand the structure of such a model, we will print the five first elements of one of the "<em>On the Origin of Species</em>" BoW model.</p>

# %%
# Load the functions allowing to create and use dictionaries
from gensim import corpora

# Create a dictionary from the stemmed tokens
dictionary = corpora.Dictionary(texts_stem)

# Create a bag-of-words model for each book, using the previously generated dictionary
bows = [dictionary.doc2bow(text) for text in texts_stem]


# Print the first five elements of the On the Origin of species' BoW model
bows[ori][0:5]
# Out:
# [(0, 11), (5, 51), (6, 1), (8, 2), (21, 1)]

# %% [markdown]
# ## 7. The most common words of a given book
# <p>The results returned by the bag-of-words model is certainly easy to use for a computer but hard to interpret for a human. It is not straightforward to understand which stemmed tokens are present in a given book from Charles Darwin, and how many occurrences we can find.</p>
# <p>In order to better understand how the model has been generated and visualize its content, we will transform it into a DataFrame and display the 10 most common stems for the book "<em>On the Origin of Species</em>".</p>

# %%
import pandas as pd

# Convert the BoW model for "On the Origin of Species" into a DataFrame
df_bow_origin = pd.DataFrame(bows[ori])

# Add the column names to the DataFrame
df_bow_origin.columns = ["index", "occurrences"]

# Add a column containing the token corresponding to the dictionary index
df_bow_origin["token"] = [dictionary[index] for index in df_bow_origin["index"]]

# Sort the DataFrame by descending number of occurrences and print the first 10 values
df_bow_origin.sort_values(by="occurrences", ascending=False).head(10)
# Out:
#       index  occurrences  token
# 739    1155         2023   have
# 1107   1718         1558     on
# 1468   2258         1543  speci
# 881    1351         1480     it
# 239     391         1362     by
# 1116   1728         1201     or
# 124     217         1140    are
# 657    1031         1137   from
# 1746   2662         1000   with
# 1591   2424          962   this

# %% [markdown]
# ## 8. Build a tf-idf model
# <p>If it wasn't for the presence of the stem "<em>speci</em>", we would have a hard time to guess this BoW model comes from the <em>On the Origin of Species</em> book. The most recurring words are, apart from few exceptions, very common and unlikely to carry any information peculiar to the given book. We need to use an additional step in order to determine which tokens are the most specific to a book.</p>
# <p>To do so, we will use a <strong>tf-idf model</strong> (term frequency–inverse document frequency). This model defines the importance of each word depending on how frequent it is in this text and how infrequent it is in all the other documents. As a result, a high tf-idf score for a word will indicate that this word is specific to this text.</p>
# <p>After computing those scores, we will print the 10 words most specific to the "<em>On the Origin of Species</em>" book (i.e., the 10 words with the highest tf-idf score).</p>

# %%
# Load the gensim functions that will allow us to generate tf-idf models
from gensim.models import TfidfModel

# Generate the tf-idf model
model = TfidfModel(bows)

# Print the model for "On the Origin of Species"
model[bows[ori]]
# Out:
# [(8, 0.0002039349037504146),
#  (21, 0.0005718916717738964),
#  (23, 0.001712732114004366),
#  (27, 0.0006461523409733151),
#  (28, 0.002569098171006549),
#  (31, 0.000856366057002183),
#  (35, 0.0010154853149893159),
#  (36, 0.0010154853149893159),
#  (51, 0.0008871872864308386),
#  (54, 0.0020309706299786318),
#  (56, 0.0023769155922479697),
#  (57, 0.0001019674518752073),
#  (63, 0.002755855423992279),
#  (64, 0.0005098372593760365),
#  (66, 0.0002039349037504146),
#  (67, 0.0023769155922479697),
#  (68, 0.0020309706299786318),
#  (75, 0.0013779277119961395),
#  (76, 0.0004435936432154193),
#  (78, 0.004173944693376085),
#  (80, 0.0020869723466880423),
#  (83, 0.008578375076608446),
#  (84, 0.0005098372593760365),
#  (88, 0.0024472188450049754),
#  (89, 0.0033649259118818413),
#  (90, 0.0008871872864308386),
#  (91, 0.0016755941981365856),
#  (94, 0.0008871872864308386),
#  (95, 0.0004435936432154193),
#  (96, 0.0035487491457233543),
#  (2292, 0.003992342788938773),
#  (2295, 0.14826085598844013),
#  (2298, 0.0010154853149893159),
#  (2300, 0.04289187538304224),
#  (2302, 0.002094492747670732),
#  (2305, 0.004003241702417275),
#  (2306, 0.011170338464882475),
#  (2307, 0.003174753973526425),
#  (2309, 0.003059023556256219),
#  (2310, 0.037204048223895766),
#  (2312, 0.0014661449233695125),
#  (2313, 0.002569098171006549),
#  (2314, 0.0014661449233695125),
#  (2320, 0.0013307809296462577),
#  (2321, 0.0009692285114599727),
#  (2324, 0.06877732956511456),
#  (2326, 0.0015873769867632125),
#  (2328, 0.00265115374875539),
#  (2330, 0.0006461523409733151),
#  (2331, 0.007443623986890134),
#  (2335, 0.027418103504711532),
#  (2336, 0.004254267808151416),
#  (2337, 0.0013779277119961395),
#  (2341, 0.004996405141885158),
#  (2342, 0.003059023556256219),
#  (2343, 0.008578375076608446),
#  (2346, 0.0020309706299786318),
#  (2347, 0.0016755941981365856),
#  (2348, 0.0008871872864308386),
#  (2350, 0.0006461523409733151),
#  (2352, 0.00032307617048665756),
#  (2354, 0.004254267808151416),
#  (2357, 0.0006283478243012196),
#  (2358, 0.002039349037504146),
#  (2361, 0.006260917040064127),
#  (2364, 0.011089841080385483),
#  (2366, 0.0010154853149893159),
#  (2373, 0.016546492706598782),
#  (2374, 0.019015324737983758),
#  (2382, 0.0007090446346919028),
#  (2383, 0.004133783135988419),
#  (2384, 0.0013779277119961395),
#  (2385, 0.0013307809296462577),
#  (2386, 0.010646247437170062),
#  (2387, 0.014194996582893417),
#  (2388, 0.0019384570229199454),
#  (2396, 0.0004435936432154193),
#  (2397, 0.0031609910081314262),
#  (2398, 0.0001019674518752073),
#  (2399, 0.002094492747670732),
#  (2409, 0.0005718916717738964),
#  (2411, 0.029113449192623174),
#  (2414, 0.004762130960289638),
#  (2419, 0.0035487491457233543),
#  (2422, 0.0006283478243012196),
#  (2423, 0.0016755941981365856),
#  (2427, 0.0016755941981365856),
#  (2431, 0.013892275330926275),
#  (2440, 0.0020869723466880423),
#  (2441, 0.0011884577961239848),
#  (2442, 0.0011437833435477929),
#  (2443, 0.007707294513019647),
#  (2444, 0.0015295117781281096),
#  ...]

# %% [markdown]
# ## 9. The results of the tf-idf model
# <p>Once again, the format of those results is hard to interpret for a human. Therefore, we will transform it into a more readable version and display the 10 most specific words for the "<em>On the Origin of Species</em>" book.</p>

# %%
# Convert the tf-idf model for "On the Origin of Species" into a DataFrame
df_tfidf = pd.DataFrame(model[bows[ori]])

# Name the columns of the DataFrame id and score
df_tfidf.columns=["id", "score"]

# Add the tokens corresponding to the numerical indices for better readability
df_tfidf['token'] = [dictionary[i] for i in list(df_tfidf["id"])]

# Sort the DataFrame by descending tf-idf score and print the first 10 rows.
df_tfidf.sort_values(by="score", ascending=False).head(10)
# Out:
#          id     score      token
# 872    2136  0.327579     select
# 3049  10001  0.204010     pigeon
# 129     367  0.197821      breed
# 2931   9289  0.167580     migrat
# 938    2295  0.148261     steril
# 282     743  0.146063     domest
# 498    1241  0.128337     hybrid
# 365     955  0.127599     fertil
# 3773  15879  0.124454    gärtner
# 3476  12594  0.121258  naturalis

# %% [markdown]
# ## 10. Compute distance between texts
# <p>The results of the tf-idf algorithm now return stemmed tokens which are specific to each book. We can, for example, see that topics such as selection, breeding or domestication are defining "<em>On the Origin of Species</em>" (and yes, in this book, Charles Darwin talks quite a lot about pigeons too). Now that we have a model associating tokens to how specific they are to each book, we can measure how related to books are between each other.</p>
# <p>To this purpose, we will use a measure of similarity called <strong>cosine similarity</strong> and we will visualize the results as a distance matrix, i.e., a matrix showing all pairwise distances between Darwin's books.</p>

# %%
# Load the library allowing similarity computations
from gensim import similarities

# Compute the similarity matrix (pairwise distance between all texts)
sims = similarities.MatrixSimilarity(model[bows])

# Transform the resulting list into a DataFrame
sim_df = pd.DataFrame(list(sims))

# Add the titles of the books as columns and index of the DataFrame
sim_df.columns = titles
sim_df.index = titles

# Print the resulting matrix
sim_df
# Out:
#                                      Autobiography  CoralReefs  DescentofMan  \
# Autobiography                             1.000000    0.050362      0.080844
# CoralReefs                                0.050362    1.000000      0.009720
# DescentofMan                              0.080844    0.009720      1.000000
# DifferentFormsofFlowers                   0.066772    0.001990      0.072712
# EffectsCrossSelfFertilization             0.077020    0.001936      0.029949
# ExpressionofEmotionManAnimals             0.090481    0.005096      0.149199
# FormationVegetableMould                   0.041032    0.029775      0.027012
# FoundationsOriginofSpecies                0.059099    0.022231      0.134861
# GeologicalObservationsSouthAmerica        0.030645    0.061191      0.009512
# InsectivorousPlants                       0.014635    0.002244      0.009240
# LifeandLettersVol1                        0.407206    0.032578      0.062203
# LifeandLettersVol2                        0.221966    0.018477      0.083587
# MonographCirripedia                       0.005870    0.006359      0.053286
# MonographCirripediaVol2                   0.008440    0.010596      0.042847
# MovementClimbingPlants                    0.023065    0.001523      0.005129
# OriginofSpecies                           0.101032    0.039514      0.267863
# PowerMovementPlants                       0.015925    0.002682      0.011114
# VariationPlantsAnimalsDomestication       0.049047    0.011443      0.228054
# VolcanicIslands                           0.038637    0.057955      0.007875
# VoyageBeagle                              0.186226    0.251962      0.125031
#
#                                      DifferentFormsofFlowers  \
# Autobiography                                       0.066772
# CoralReefs                                          0.001990
# DescentofMan                                        0.072712
# DifferentFormsofFlowers                             1.000000
# EffectsCrossSelfFertilization                       0.391672
# ExpressionofEmotionManAnimals                       0.006574
# FormationVegetableMould                             0.010574
# FoundationsOriginofSpecies                          0.039990
# GeologicalObservationsSouthAmerica                  0.002821
# InsectivorousPlants                                 0.007315
# LifeandLettersVol1                                  0.016690
# LifeandLettersVol2                                  0.048390
# MonographCirripedia                                 0.009382
# MonographCirripediaVol2                             0.005436
# MovementClimbingPlants                              0.008169
# OriginofSpecies                                     0.129109
# PowerMovementPlants                                 0.018810
# VariationPlantsAnimalsDomestication                 0.049374
# VolcanicIslands                                     0.002623
# VoyageBeagle                                        0.013188
#
#                                      EffectsCrossSelfFertilization  \
# Autobiography                                             0.077020
# CoralReefs                                                0.001936
# DescentofMan                                              0.029949
# DifferentFormsofFlowers                                   0.391672
# EffectsCrossSelfFertilization                             1.000000
# ExpressionofEmotionManAnimals                             0.006925
# FormationVegetableMould                                   0.032301
# FoundationsOriginofSpecies                                0.040346
# GeologicalObservationsSouthAmerica                        0.002232
# InsectivorousPlants                                       0.006611
# LifeandLettersVol1                                        0.020375
# LifeandLettersVol2                                        0.048435
# MonographCirripedia                                       0.003206
# MonographCirripediaVol2                                   0.002940
# MovementClimbingPlants                                    0.014937
# OriginofSpecies                                           0.146790
# PowerMovementPlants                                       0.039514
# VariationPlantsAnimalsDomestication                       0.054479
# VolcanicIslands                                           0.002168
# VoyageBeagle                                              0.017190
#
#                                      ExpressionofEmotionManAnimals  \
# Autobiography                                             0.090481
# CoralReefs                                                0.005096
# DescentofMan                                              0.149199
# DifferentFormsofFlowers                                   0.006574
# EffectsCrossSelfFertilization                             0.006925
# ExpressionofEmotionManAnimals                             1.000000
# FormationVegetableMould                                   0.021082
# FoundationsOriginofSpecies                                0.047543
# GeologicalObservationsSouthAmerica                        0.005209
# InsectivorousPlants                                       0.011177
# LifeandLettersVol1                                        0.068586
# LifeandLettersVol2                                        0.051709
# MonographCirripedia                                       0.016836
# MonographCirripediaVol2                                   0.029732
# MovementClimbingPlants                                    0.005920
# OriginofSpecies                                           0.063055
# PowerMovementPlants                                       0.011157
# VariationPlantsAnimalsDomestication                       0.083667
# VolcanicIslands                                           0.005588
# VoyageBeagle                                              0.101256
#
#                                      FormationVegetableMould  \
# Autobiography                                       0.041032
# CoralReefs                                          0.029775
# DescentofMan                                        0.027012
# DifferentFormsofFlowers                             0.010574
# EffectsCrossSelfFertilization                       0.032301
# ExpressionofEmotionManAnimals                       0.021082
# FormationVegetableMould                             1.000000
# FoundationsOriginofSpecies                          0.021439
# GeologicalObservationsSouthAmerica                  0.066686
# InsectivorousPlants                                 0.035325
# LifeandLettersVol1                                  0.029096
# LifeandLettersVol2                                  0.024675
# MonographCirripedia                                 0.019609
# MonographCirripediaVol2                             0.023773
# MovementClimbingPlants                              0.039103
# OriginofSpecies                                     0.049204
# PowerMovementPlants                                 0.039439
# VariationPlantsAnimalsDomestication                 0.032426
# VolcanicIslands                                     0.059083
# VoyageBeagle                                        0.098597
#
#                                      FoundationsOriginofSpecies  \
# Autobiography                                          0.059099
# CoralReefs                                             0.022231
# DescentofMan                                           0.134861
# DifferentFormsofFlowers                                0.039990
# EffectsCrossSelfFertilization                          0.040346
# ExpressionofEmotionManAnimals                          0.047543
# FormationVegetableMould                                0.021439
# FoundationsOriginofSpecies                             1.000000
# GeologicalObservationsSouthAmerica                     0.027123
# InsectivorousPlants                                    0.005856
# LifeandLettersVol1                                     0.059713
# LifeandLettersVol2                                     0.056703
# MonographCirripedia                                    0.007647
# MonographCirripediaVol2                                0.010730
# MovementClimbingPlants                                 0.003933
# OriginofSpecies                                        0.322623
# PowerMovementPlants                                    0.008638
# VariationPlantsAnimalsDomestication                    0.196559
# VolcanicIslands                                        0.017449
# VoyageBeagle                                           0.089619
#
#                                      GeologicalObservationsSouthAmerica  \
# Autobiography                                                  0.030645
# CoralReefs                                                     0.061191
# DescentofMan                                                   0.009512
# DifferentFormsofFlowers                                        0.002821
# EffectsCrossSelfFertilization                                  0.002232
# ExpressionofEmotionManAnimals                                  0.005209
# FormationVegetableMould                                        0.066686
# FoundationsOriginofSpecies                                     0.027123
# GeologicalObservationsSouthAmerica                             1.000000
# InsectivorousPlants                                            0.006627
# LifeandLettersVol1                                             0.029463
# LifeandLettersVol2                                             0.012573
# MonographCirripedia                                            0.009124
# MonographCirripediaVol2                                        0.023355
# MovementClimbingPlants                                         0.001988
# OriginofSpecies                                                0.052431
# PowerMovementPlants                                            0.003379
# VariationPlantsAnimalsDomestication                            0.013599
# VolcanicIslands                                                0.371997
# VoyageBeagle                                                   0.262653
#
#                                      InsectivorousPlants  LifeandLettersVol1  \
# Autobiography                                   0.014635            0.407206
# CoralReefs                                      0.002244            0.032578
# DescentofMan                                    0.009240            0.062203
# DifferentFormsofFlowers                         0.007315            0.016690
# EffectsCrossSelfFertilization                   0.006611            0.020375
# ExpressionofEmotionManAnimals                   0.011177            0.068586
# FormationVegetableMould                         0.035325            0.029096
# FoundationsOriginofSpecies                      0.005856            0.059713
# GeologicalObservationsSouthAmerica              0.006627            0.029463
# InsectivorousPlants                             1.000000            0.006204
# LifeandLettersVol1                              0.006204            1.000000
# LifeandLettersVol2                              0.016819            0.878084
# MonographCirripedia                             0.018659            0.006003
# MonographCirripediaVol2                         0.019220            0.013060
# MovementClimbingPlants                          0.253248            0.005685
# OriginofSpecies                                 0.014595            0.101382
# PowerMovementPlants                             0.022071            0.009554
# VariationPlantsAnimalsDomestication             0.010004            0.056703
# VolcanicIslands                                 0.008328            0.027319
# VoyageBeagle                                    0.014509            0.179331
#
#                                      LifeandLettersVol2  MonographCirripedia  \
# Autobiography                                  0.221966             0.005870
# CoralReefs                                     0.018477             0.006359
# DescentofMan                                   0.083587             0.053286
# DifferentFormsofFlowers                        0.048390             0.009382
# EffectsCrossSelfFertilization                  0.048435             0.003206
# ExpressionofEmotionManAnimals                  0.051709             0.016836
# FormationVegetableMould                        0.024675             0.019609
# FoundationsOriginofSpecies                     0.056703             0.007647
# GeologicalObservationsSouthAmerica             0.012573             0.009124
# InsectivorousPlants                            0.016819             0.018659
# LifeandLettersVol1                             0.878084             0.006003
# LifeandLettersVol2                             1.000000             0.005121
# MonographCirripedia                            0.005121             1.000000
# MonographCirripediaVol2                        0.010965             0.515742
# MovementClimbingPlants                         0.018340             0.012417
# OriginofSpecies                                0.101159             0.031279
# PowerMovementPlants                            0.012366             0.018495
# VariationPlantsAnimalsDomestication            0.052147             0.022861
# VolcanicIslands                                0.012305             0.010033
# VoyageBeagle                                   0.094677             0.014245
#
#                                      MonographCirripediaVol2  \
# Autobiography                                       0.008440
# CoralReefs                                          0.010596
# DescentofMan                                        0.042847
# DifferentFormsofFlowers                             0.005436
# EffectsCrossSelfFertilization                       0.002940
# ExpressionofEmotionManAnimals                       0.029732
# FormationVegetableMould                             0.023773
# FoundationsOriginofSpecies                          0.010730
# GeologicalObservationsSouthAmerica                  0.023355
# InsectivorousPlants                                 0.019220
# LifeandLettersVol1                                  0.013060
# LifeandLettersVol2                                  0.010965
# MonographCirripedia                                 0.515742
# MonographCirripediaVol2                             1.000000
# MovementClimbingPlants                              0.006717
# OriginofSpecies                                     0.037801
# PowerMovementPlants                                 0.022128
# VariationPlantsAnimalsDomestication                 0.029569
# VolcanicIslands                                     0.016373
# VoyageBeagle                                        0.024882
#
#                                      MovementClimbingPlants  OriginofSpecies  \
# Autobiography                                      0.023065         0.101032
# CoralReefs                                         0.001523         0.039514
# DescentofMan                                       0.005129         0.267863
# DifferentFormsofFlowers                            0.008169         0.129109
# EffectsCrossSelfFertilization                      0.014937         0.146790
# ExpressionofEmotionManAnimals                      0.005920         0.063055
# FormationVegetableMould                            0.039103         0.049204
# FoundationsOriginofSpecies                         0.003933         0.322623
# GeologicalObservationsSouthAmerica                 0.001988         0.052431
# InsectivorousPlants                                0.253248         0.014595
# LifeandLettersVol1                                 0.005685         0.101382
# LifeandLettersVol2                                 0.018340         0.101159
# MonographCirripedia                                0.012417         0.031279
# MonographCirripediaVol2                            0.006717         0.037801
# MovementClimbingPlants                             1.000000         0.008809
# OriginofSpecies                                    0.008809         1.000000
# PowerMovementPlants                                0.104259         0.018113
# VariationPlantsAnimalsDomestication                0.011270         0.403708
# VolcanicIslands                                    0.002820         0.035797
# VoyageBeagle                                       0.012335         0.165915
#
#                                      PowerMovementPlants  \
# Autobiography                                   0.015925
# CoralReefs                                      0.002682
# DescentofMan                                    0.011114
# DifferentFormsofFlowers                         0.018810
# EffectsCrossSelfFertilization                   0.039514
# ExpressionofEmotionManAnimals                   0.011157
# FormationVegetableMould                         0.039439
# FoundationsOriginofSpecies                      0.008638
# GeologicalObservationsSouthAmerica              0.003379
# InsectivorousPlants                             0.022071
# LifeandLettersVol1                              0.009554
# LifeandLettersVol2                              0.012366
# MonographCirripedia                             0.018495
# MonographCirripediaVol2                         0.022128
# MovementClimbingPlants                          0.104259
# OriginofSpecies                                 0.018113
# PowerMovementPlants                             1.000000
# VariationPlantsAnimalsDomestication             0.020151
# VolcanicIslands                                 0.003768
# VoyageBeagle                                    0.023084
#
#                                      VariationPlantsAnimalsDomestication  \
# Autobiography                                                   0.049047
# CoralReefs                                                      0.011443
# DescentofMan                                                    0.228054
# DifferentFormsofFlowers                                         0.049374
# EffectsCrossSelfFertilization                                   0.054479
# ExpressionofEmotionManAnimals                                   0.083667
# FormationVegetableMould                                         0.032426
# FoundationsOriginofSpecies                                      0.196559
# GeologicalObservationsSouthAmerica                              0.013599
# InsectivorousPlants                                             0.010004
# LifeandLettersVol1                                              0.056703
# LifeandLettersVol2                                              0.052147
# MonographCirripedia                                             0.022861
# MonographCirripediaVol2                                         0.029569
# MovementClimbingPlants                                          0.011270
# OriginofSpecies                                                 0.403708
# PowerMovementPlants                                             0.020151
# VariationPlantsAnimalsDomestication                             1.000000
# VolcanicIslands                                                 0.012190
# VoyageBeagle                                                    0.113347
#
#                                      VolcanicIslands  VoyageBeagle
# Autobiography                               0.038637      0.186226
# CoralReefs                                  0.057955      0.251962
# DescentofMan                                0.007875      0.125031
# DifferentFormsofFlowers                     0.002623      0.013188
# EffectsCrossSelfFertilization               0.002168      0.017190
# ExpressionofEmotionManAnimals               0.005588      0.101256
# FormationVegetableMould                     0.059083      0.098597
# FoundationsOriginofSpecies                  0.017449      0.089619
# GeologicalObservationsSouthAmerica          0.371997      0.262653
# InsectivorousPlants                         0.008328      0.014509
# LifeandLettersVol1                          0.027319      0.179331
# LifeandLettersVol2                          0.012305      0.094677
# MonographCirripedia                         0.010033      0.014245
# MonographCirripediaVol2                     0.016373      0.024882
# MovementClimbingPlants                      0.002820      0.012335
# OriginofSpecies                             0.035797      0.165915
# PowerMovementPlants                         0.003768      0.023084
# VariationPlantsAnimalsDomestication         0.012190      0.113347
# VolcanicIslands                             1.000000      0.139005
# VoyageBeagle                                0.139005      1.000000

# %% [markdown]
# ## 11. The book most similar to "On the Origin of Species"
# <p>We now have a matrix containing all the similarity measures between any pair of books from Charles Darwin! We can now use this matrix to quickly extract the information we need, i.e., the distance between one book and one or several others. </p>
# <p>As a first step, we will display which books are the most similar to "<em>On the Origin of Species</em>," more specifically we will produce a bar chart showing all books ranked by how similar they are to Darwin's landmark work.</p>

# %%
# This is needed to display plots in a notebook
# %matplotlib inline

# Import the needed functions from matplotlib
import matplotlib.pyplot as plt

# Select the column corresponding to "On the Origin of Species" and 
v = sim_df["OriginofSpecies"]

# Sort by ascending scores
v_sorted = v.sort_values(ascending=True)

# Plot this data has a horizontal bar plot
v_sorted.plot.barh(x='lab', y='val', rot=0).plot()

# Modify the axes labels and plot title for better readability
plt.xlabel("Cosine distance")
plt.ylabel("")
plt.title("Most similar books to 'On the Origin of Species'")
# Out:
# Text(0.5, 1.0, "Most similar books to 'On the Origin of Species'")

# %% [markdown]
# ## 12. Which books have similar content?
# <p>This turns out to be extremely useful if we want to determine a given book's most similar work. For example, we have just seen that if you enjoyed "<em>On the Origin of Species</em>," you can read books discussing similar concepts such as "<em>The Variation of Animals and Plants under Domestication</em>" or "<em>The Descent of Man, and Selection in Relation to Sex</em>." If you are familiar with Darwin's work, these suggestions will likely seem natural to you. Indeed, <em>On the Origin of Species</em> has a whole chapter about domestication and <em>The Descent of Man, and Selection in Relation to Sex</em> applies the theory of natural selection to human evolution. Hence, the results make sense.</p>
# <p>However, we now want to have a better understanding of the big picture and see how Darwin's books are generally related to each other (in terms of topics discussed). To this purpose, we will represent the whole similarity matrix as a dendrogram, which is a standard tool to display such data. <strong>This last approach will display all the information about book similarities at once.</strong> For example, we can find a book's closest relative but, also, we can visualize which groups of books have similar topics (e.g., the cluster about Charles Darwin personal life with his autobiography and letters). If you are familiar with Darwin's bibliography, the results should not surprise you too much, which indicates the method gives good results. Otherwise, next time you read one of the author's book, you will know which other books to read next in order to learn more about the topics it addressed.</p>

# %%
# Import libraries
from scipy.cluster import hierarchy

# Compute the clusters from the similarity matrix,
# using the Ward variance minimization algorithm
Z = hierarchy.linkage(sim_df, 'ward')

# Display this result as a horizontal dendrogram
a = hierarchy.dendrogram(Z,  leaf_font_size=8, labels=sim_df.index,  orientation="left")
